# %%
import sys
sys.path.append("..")


from Extractor import MultiPDFExtractor

pdf_dir = "../articles-lite"  # Directory containing PDF files
extractor = MultiPDFExtractor(pdf_directory=pdf_dir)
extractor.run_pipeline()
print("Processing complete. Vector database is constructed and persisted.")
# Out:
# -----------------------------  Processing PDFs...  -----------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 10
#       8 pdf_dir = "../articles-lite"  # Directory containing PDF files
#       9 extractor = MultiPDFExtractor(pdf_directory=pdf_dir)
# ---> 10 extractor.run_pipeline()
#      11 print("Processing complete. Vector database is constructed and persisted.")
#
# File c:\Users\hp\pjr\notebooks\..\Extractor.py:265, in MultiPDFExtractor.run_pipeline(self)
#     260 def run_pipeline(self):
#     262     print(
#     263         f"-----------------------------  Processing PDFs...  -----------------------------"
#     264     )
# --> 265     docs = self.load_pdfs()
#     267     print(f"loaded {len(docs)} PDFs ✅")
#     269     for d in docs:
#
# File c:\Users\hp\pjr\notebooks\..\Extractor.py:80, in MultiPDFExtractor.load_pdfs(self)
#      73 """
#      74 Load all PDFs from the directory as a list of LangChain Documents.
#      75 Each PDF will return a list of Documents (usually one Document per PDF).
#      76 """
#      77 loader = DirectoryLoader(
#      78     self.pdf_directory, glob="*.pdf", loader_cls=PyPDFLoader
#      79 )
# ---> 80 docs = loader.load()
#      82 all_files = os.listdir(self.pdf_directory)
#      84 # Filter for .pdf files (case-insensitive)
#
# File c:\Users\hp\anaconda3\envs\llmm\lib\site-packages\langchain_community\document_loaders\directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File c:\Users\hp\anaconda3\envs\llmm\lib\site-packages\langchain_community\document_loaders\directory.py:195, in DirectoryLoader.lazy_load(self)
#     193 else:
#     194     for i in items:
# --> 195         yield from self._lazy_load_file(i, p, pbar)
#     197 if pbar:
#     198     pbar.close()
#
# File c:\Users\hp\anaconda3\envs\llmm\lib\site-packages\langchain_community\document_loaders\directory.py:223, in DirectoryLoader._lazy_load_file(self, item, path, pbar)
#     221 loader = self.loader_cls(str(item), **self.loader_kwargs)
#     222 try:
# --> 223     for subdoc in loader.lazy_load():
#     224         yield subdoc
#     225 except NotImplementedError:
#
# File c:\Users\hp\anaconda3\envs\llmm\lib\site-packages\langchain_community\document_loaders\pdf.py:257, in PyPDFLoader.lazy_load(self)
#     255 else:
#     256     blob = Blob.from_path(self.file_path)  # type: ignore[attr-defined]
# --> 257 yield from self.parser.parse(blob)
#
# File c:\Users\hp\anaconda3\envs\llmm\lib\site-packages\langchain_core\document_loaders\base.py:127, in BaseBlobParser.parse(self, blob)
#     112 def parse(self, blob: Blob) -> list[Document]:
#     113     """Eagerly parse the blob into a document or documents.
#     114
#     115     This is a convenience method for interactive development environment.
#    (...)
#     125         List of documents
#     126     """
# --> 127     return list(self.lazy_parse(blob))
#
# File c:\Users\hp\anaconda3\envs\llmm\lib\site-packages\langchain_community\document_loaders\parsers\pdf.py:125, in PyPDFParser.lazy_parse(self, blob)
#     122 with blob.as_bytes_io() as pdf_file_obj:  # type: ignore[attr-defined]
#     123     pdf_reader = pypdf.PdfReader(pdf_file_obj, password=self.password)
# --> 125     yield from [
#     126         Document(
#     127             page_content=_extract_text_from_page(page=page)
#     128             + self._extract_images_from_page(page),
#     129             metadata={"source": blob.source, "page": page_number},  # type: ignore[attr-defined]
#     130         )
#     131         for page_number, page in enumerate(pdf_reader.pages)
#     132     ]
#
# File c:\Users\hp\anaconda3\envs\llmm\lib\site-packages\langchain_community\document_loaders\parsers\pdf.py:127, in <listcomp>(.0)
#     122 with blob.as_bytes_io() as pdf_file_obj:  # type: ignore[attr-defined]
#     123     pdf_reader = pypdf.PdfReader(pdf_file_obj, password=self.password)
#     125     yield from [
#     126         Document(
# --> 127             page_content=_extract_text_from_page(page=page)
#     128             + self._extract_images_from_page(page),
#     129             metadata={"source": blob.source, "page": page_number},  # type: ignore[attr-defined]
#     130         )
#     131         for page_number, page in enumerate(pdf_reader.pages)
#     132     ]
#
# File c:\Users\hp\anaconda3\envs\llmm\lib\site-packages\langchain_community\document_loaders\parsers\pdf.py:117, in PyPDFParser.lazy_parse.<locals>._extract_text_from_page(page)
#     115     return page.extract_text()
#     116 else:
# --> 117     return page.extract_text(
#     118         extraction_mode=self.extraction_mode,  # type: ignore[arg-type]
#     119         **self.extraction_kwargs,  # type: ignore[arg-type]
#     120     )
#
# File c:\Users\hp\anaconda3\envs\llmm\lib\site-packages\pypdf\_page.py:2393, in PageObject.extract_text(self, orientations, space_width, visitor_operand_before, visitor_operand_after, visitor_text, extraction_mode, *args, **kwargs)
#    2390 if isinstance(orientations, int):
#    2391     orientations = (orientations,)
# -> 2393 return self._extract_text(
#    2394     self,
#    2395     self.pdf,
#    2396     orientations,
#    2397     space_width,
#    2398     PG.CONTENTS,
#    2399     visitor_operand_before,
#    2400     visitor_operand_after,
#    2401     visitor_text,
#    2402 )
#
# File c:\Users\hp\anaconda3\envs\llmm\lib\site-packages\pypdf\_page.py:2115, in PageObject._extract_text(self, obj, pdf, orientations, space_width, content_key, visitor_operand_before, visitor_operand_after, visitor_text)
#    2109             process_operation(b"Tj", [op])
#    2110         if isinstance(op, (int, float, NumberObject, FloatObject)) and (
#    2111             (abs(float(op)) >= _confirm_space_width)
#    2112             and (len(text) > 0)
#    2113             and (text[-1] != " ")
#    2114         ):
# -> 2115             process_operation(b"Tj", [" "])
#    2116 elif operator == b"Do":
#    2117     output += text
#
# File c:\Users\hp\anaconda3\envs\llmm\lib\site-packages\pypdf\_page.py:2069, in PageObject._extract_text.<locals>.process_operation(operator, operands)
#    2067 if check_crlf_space:
#    2068     try:
# -> 2069         text, output, cm_prev, tm_prev = crlf_space_check(
#    2070             text,
#    2071             (cm_prev, tm_prev),
#    2072             (cm_matrix, tm_matrix),
#    2073             (memo_cm, memo_tm),
#    2074             cmap,
#    2075             orientations,
#    2076             output,
#    2077             font_size,
#    2078             visitor_text,
#    2079             str_widths,
#    2080             compute_strwidths(_actual_str_size["space_width"]),
#    2081             _actual_str_size["str_height"]
#    2082         )
#    2083         if text == "":
#    2084             memo_cm = cm_matrix.copy()
#
# File c:\Users\hp\anaconda3\envs\llmm\lib\site-packages\pypdf\_text_extraction\__init__.py:114, in crlf_space_check(text, cmtm_prev, cmtm_matrix, memo_cmtm, cmap, orientations, output, font_size, visitor_text, str_widths, spacewidth, str_height)
#     111 memo_tm = memo_cmtm[1]
#     113 m_prev = mult(tm_prev, cm_prev)
# --> 114 m = mult(tm_matrix, cm_matrix)
#     115 orientation = orient(m)
#     116 delta_x = m[4] - m_prev[4]
#
# File c:\Users\hp\anaconda3\envs\llmm\lib\site-packages\pypdf\_text_extraction\__init__.py:75, in mult(m, n)
#      68 def mult(m: List[float], n: List[float]) -> List[float]:
#      69     return [
#      70         m[0] * n[0] + m[1] * n[2],
#      71         m[0] * n[1] + m[1] * n[3],
#      72         m[2] * n[0] + m[3] * n[2],
#      73         m[2] * n[1] + m[3] * n[3],
#      74         m[4] * n[0] + m[5] * n[2] + n[4],
# ---> 75         m[4] * n[1] + m[5] * n[3] + n[5],
#      76     ]
#
# KeyboardInterrupt:
